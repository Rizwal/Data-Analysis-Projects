# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# # DISTRIBUTION PLOTS(distplots) FOR NUMERIC VALUES

# %%
sns.displot(x='Age',data=df,kde=True)

# %%
sns.distplot(df['Age'],hist=True,kde=False)
# Out:
# C:\Users\Rizwal\AppData\Local\Temp\ipykernel_7736\2175098754.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=True,kde=False)
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(df['Age'],hist=False,kde=False,rug=True)
# Out:
# C:\Users\Rizwal\AppData\Local\Temp\ipykernel_7736\227310382.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=False,kde=False,rug=True)
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(df['Age'],hist=True,kde=False,bins=5)
# Out:
# C:\Users\Rizwal\AppData\Local\Temp\ipykernel_7736\432472549.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=True,kde=False,bins=5)
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(df['RestingBP'],color='red')
# Out:
# C:\Users\Rizwal\AppData\Local\Temp\ipykernel_7736\1985958539.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'],color='red')
# <AxesSubplot:xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'],color='red')
# Out:
# C:\Users\Rizwal\AppData\Local\Temp\ipykernel_7736\3369498721.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'],color='red')
# <AxesSubplot:xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['FastingBS'],color='red')
# Out:
# C:\Users\Rizwal\AppData\Local\Temp\ipykernel_7736\519634133.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['FastingBS'],color='red')
# <AxesSubplot:xlabel='FastingBS', ylabel='Density'>

# %% [markdown]
# # PIE CHARTS FOR CATEGORICAL COLUMNS

# %%
df.groupby('Sex').size().plot(kind='pie',autopct='%.1f')
# Out:
# <AxesSubplot:>

# %%
df.groupby('ChestPainType').size().plot(kind='pie',autopct='%.1f')
# Out:
# <AxesSubplot:>

# %%
df.groupby('RestingECG').size().plot(kind='pie',autopct='%.1f')
# Out:
# <AxesSubplot:>

# %%
df.groupby('ST_Slope').size().plot(kind='pie',autopct='%.1f')
# Out:
# <AxesSubplot:>

# %%
df.groupby('HeartDisease').size().plot(kind='pie',autopct='%.1f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(df['Age'])
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(y=df['Sex'],x=df['HeartDisease'])
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y=df['Age'],x=df['HeartDisease'])
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='Age'>

# %% [markdown]
# # Correlation - Heatmap

# %%
df.corr()
# Out:
# C:\Users\Rizwal\AppData\Local\Temp\ipykernel_7736\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# ...

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\Rizwal\AppData\Local\Temp\ipykernel_7736\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot:>

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# # JointPlot

# %%
sns.jointplot(x=df['Age'],y=df['MaxHR'])

# %%
    sns.jointplot(x=df['Age'],y=df['MaxHR'],kind='hex')

# %%
sns.jointplot(x=df['Age'],y=df['MaxHR'],kind='reg')

# %%
sns.jointplot(x=df['HeartDisease'],y=df['MaxHR'],kind='reg')
